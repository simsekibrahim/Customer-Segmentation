# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___

# %% [markdown]
# # WELCOME!

# %% [markdown]
# Welcome to "RFM Customer Segmentation & Cohort Analysis Project". This is the first project of the Capstone Project Series, which consists of 3 different project that contain different scenarios.
#
# This is a project which you will learn what is RFM? And how to apply RFM Analysis and Customer Segmentation using K-Means Clustering. Also you will improve your Data Cleaning, Data Visualization and Exploratory Data Analysis capabilities. On the other hand you will create Cohort and Conduct Cohort Analysis.
#
# Before diving into the project, please take a look at the determines and project structure.
#
# - **NOTE:** This Project assumes that you already know the basics of coding in Python and are familiar with the theory behind K-Means Clustering.
#
# "RFM Müşteri Segmentasyon ve Kohort Analiz Projesi" na hoş geldiniz.Bu, farklı senaryolar içeren 3 farklı projeden oluşan Capstone Project serisinin ilk projesidir.
#
# Bu, RFM'nin ne olduğunu öğreneceğiniz bir proje mi?Ve K-Means kümelenmesi kullanarak RFM analizi ve müşteri segmentasyonu nasıl uygulanır.Ayrıca veri temizliği, veri görselleştirme ve keşif veri analizi özelliklerinizi geliştireceksiniz.Öte yandan kohort oluşturacak ve kohort analizi yapacaksınız.
#
# Projeye dalmadan önce lütfen belirleme ve proje yapısına bir göz atın.
#
# - ** Not: ** Bu proje, Python'da kodlamanın temellerini zaten bildiğinizi ve K-ortalama kümelemesinin arkasındaki teoriye aşina olduğunuzu varsayar.

# %% [markdown]
# # #Determines
#
# Using the [Online Retail dataset](https://archive.ics.uci.edu/ml/datasets/Online+Retail) from the UCI Machine Learning Repository for exploratory data analysis, ***Customer Segmentation***, ***RFM Analysis***, ***K-Means Clustering*** and ***Cohort Analysis***.
#
# This is a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail. The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.
#
# Bu, İngiltere merkezli ve kayıtlı mağaza olmayan bir çevrimiçi perakende için 01/12/2010 ve 09/12/2011 arasında meydana gelen tüm işlemleri içeren ulusötesi bir veri setidir.Şirket esas olarak benzersiz tüm işleme hediyeleri satıyor.Şirketin birçok müşterisi toptancıdır.
#
# Feature Information:
#
# **InvoiceNo**: Invoice number. *Nominal*, a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation.
# <br>
# **StockCode**: Product (item) code. *Nominal*, a 5-digit integral number uniquely assigned to each distinct product.
# <br>
# **Description**: Product (item) name. *Nominal*.
# <br>
# **Quantity**: The quantities of each product (item) per transaction. *Numeric*.
# <br>
# **InvoiceDate**: Invoice Date and time. *Numeric*, the day and time when each transaction was generated.
# <br>
# **UnitPrice**: Unit price. *Numeric*, Product price per unit in sterling.
# <br>
# **CustomerID**: Customer number. *Nominal*, a 5-digit integral number uniquely assigned to each customer.
# <br>
# **Country**: Country name. *Nominal*, the name of the country where each customer resides.
#
#
# ---
#
#
# First of all, to observe the structure of the data and missing values, you can use exploratory data analysis and data visualization techniques.
#
# You must do descriptive analysis. Because you must understand the relationship of the features to each other and clear the noise and missing values in the data. After that, the data set will be ready for RFM analysis.
#
# Before starting the RFM Analysis, you will be asked to do some analysis regarding the distribution of *Orders*, *Customers* and *Countries*. These analyzes will help the company develop its sales policies and contribute to the correct use of resources.
#
# You will notice that the UK not only has the most sales revenue, but also the most customers. So you will continue to analyze only UK transactions in the next RFM Analysis, Customer Segmentation and K-Means Clustering topics.
#
# Next, you will begin RFM Analysis, a customer segmentation technique based on customers' past purchasing behavior.
#
# By using RFM Analysis, you can enable companies to develop different approaches to different customer segments so that they can get to know their customers better, observe trends better, and increase customer retention and sales revenues.
#
# You will calculate the Recency, Frequency and Monetary values of the customers in the RFM Analysis you will make using the data consisting of UK transactions. Ultimately, you have to create an RFM table containing these values.
#
# In the Customer Segmentation section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".
#
# We will segment the customers ourselves based on their recency, frequency, and monetary values. But can an **unsupervised learning** model do this better for us? You will use the K-Means algorithm to find the answer to this question. Then you will compare the classification made by the algorithm with the classification you have made yourself.
#
# Before applying K-Means Clustering, you should do data pre-processing. In this context, it will be useful to examine feature correlations and distributions. In addition, the data you apply for K-Means should be normalized.
#
# On the other hand, you should inform the K-means algorithm about the number of clusters it will predict. You will also try the *** Elbow method *** and *** Silhouette Analysis *** to find the optimum number of clusters.
#
# After the above operations, you will have made cluster estimation with K-Means. You should visualize the cluster distribution by using a scatter plot. You can observe the properties of the resulting clusters with the help of the boxplot. Thus you will be able to tag clusters and interpret results.
#
# Finally, you will do Cohort Analysis with the data you used at the beginning, regardless of the analysis you have done before. Cohort analysis is a subset of behavioral analytics that takes the user data and breaks them into related groups for analysis. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.

# %% [markdown]
# # #Project Structures
#
# - Data Cleaning & Exploratory Data Analysis
# - RFM Analysis
# - Customer Segmentation
# - Applying K-Means Clustering
# - Create Cohort and Conduct Cohort Analysis

# %% [markdown]
# # #Tasks
#
# #### 1. Data Cleaning & Exploratory Data Analysis
#
# - Import Modules, Load Data & Data Review
# - Follow the Steps Below
#
#     *i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.*
#
#     *ii. What does the letter "C" in the invoiceno column mean?*
#
#     *iii. Handling Missing Values*
#
#     *iv. Clean the Data from the Noise and Missing Values*
#
#     *v. Explore the Orders*
#
#     *vi. Explore Customers by Country*
#
#     *vii. Explore the UK Market*
#
# #### 2. RFM Analysis
#
# - Follow the steps below
#
#    *i. Import Libraries*
#
#    *ii. Review "df_uk" DataFrame (the df_uk what you create at the end of the Task 1)*
#
#    *iii. Calculate Recency*
#
#    *iv. Calculate Frequency*
#
#    *v. Calculate Monetary Values*
#
#    *vi. Create RFM Table*
#
# #### 3. Customer Segmentation with RFM Scores
# - Calculate RFM Scoring
#
#     *i. Creating the RFM Segmentation Table*
#
# - Plot RFM Segments
#
# #### 4. Applying K-Means Clustering
# - Data Pre-Processing and Exploring
#
#     *i. Define and Plot Feature Correlations*
#
#     *ii. Visualize Feature Distributions*
#
#     *iii. Data Normalization*
#
# - K-Means Implementation
#
#     *i. Define Optimal Cluster Number (K) by using "Elbow Method" and "Silhouette Analysis"*
#
#     *ii. Visualize the Clusters*
#
#     *iii. Assign the label*
#
#     *iv. Conclusion*
#
# #### 5. Create Cohort and Conduct Cohort Analysis
# - Future Engineering
#
#     *i. Extract the Month of the Purchase*
#
#     *ii. Calculating time offset in Months i.e. Cohort Index*
#
# - Create 1st Cohort: User Number & Retention Rate
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 1 using seaborn and matplotlib*
#
# - Create 2nd Cohort: Average Quantity Sold
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 2 using seaborn and matplotlib*
#
# - Create 3rd Cohort: Average Sales
#
#     *i. Pivot Cohort and Cohort Retention*
#
#     *ii. Visualize analysis of cohort 3 using seaborn and matplotlib*
#
# - **Note: There may be sub-tasks associated with each task, you will see them in order during the course of the work.**

# %% [markdown]
# # 1. Data Cleaning & Exploratory Data Analysis

# %% [markdown]
# ## Import Modules, Load Data & Data Review

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 10)

# %% [markdown]
# ### i. Take a look at relationships between InvoiceNo, Quantity and UnitPrice columns.
# ### Ben.Invoiceno, Miktar ve UnitPrice sütunları arasındaki ilişkilere bir göz atın.

# %% [markdown]
# We see that there are negative values in the Quantity and UnitPrice columns. These are possibly canceled and returned orders. Let's check it out.
#
# Quantity ve UnitPrice sütunlarında negatif değerler olduğunu görüyoruz. Bunlar muhtemelen iptal edilen ve iade edilen siparişlerdir. Hadi kontrol edelim.

# %%
df0 = pd.read_excel("Online Retail.xlsx")

# %%
df = df0.copy()
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df.duplicated().sum()
# Out:
# 5268

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 536641 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    536641 non-null  object
#  1   StockCode    536641 non-null  object
#  2   Description  535187 non-null  object
#  3   Quantity     536641 non-null  int64
#  4   InvoiceDate  536641 non-null  datetime64[ns]
#  5   UnitPrice    536641 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      536641 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 36.8+ MB

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  536641.000000  536641.000000  401604.000000
# mean        9.620029       4.632656   15281.160818
# std       219.130156      97.233118    1714.006089
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13939.000000
# 50%         3.000000       2.080000   15145.000000
# 75%        10.000000       4.130000   16784.000000
# max     80995.000000   38970.000000   18287.000000

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="Quantity");

# %%
plt.figure(figsize=(10,6))
sns.boxplot(data=df, x="UnitPrice");

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# dtype: int64

# %%
df.Description.value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER     2357
# REGENCY CAKESTAND 3 TIER               2189
# JUMBO BAG RED RETROSPOT                2156
# PARTY BUNTING                          1720
# LUNCH BAG RED RETROSPOT                1625
#                                        ...
# rcvd be air temp fix for dotcom sit       1
# SET 12 COLOURING PENCILS DOILEY           1
# SET 36 COLOURING PENCILS DOILEY           1
#  I LOVE LONDON MINI RUCKSACK              1
# found some more on shelf                  1
# Name: Description, Length: 4223, dtype: int64

# %%
df.Quantity.value_counts()
# Out:
#  1        144495
#  2         81245
#  12        60858
#  6         40656
#  4         38393
#            ...
# -472           1
# -161           1
# -1206          1
# -272           1
# -80995         1
# Name: Quantity, Length: 722, dtype: int64

# %%
df[df.Quantity < 0]
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 141      C536379         D                          Discount        -1
# 154      C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235      C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236      C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237      C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
# ...          ...       ...                               ...       ...
# 540449   C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 541541   C581499         M                            Manual        -1
# 541715   C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 541716   C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 541717   C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df.InvoiceNo == "C536391"]
# Out:
#     InvoiceNo StockCode                        Description  Quantity  \
# 235   C536391     22556     PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984   PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983   PACK OF 12 BLUE PAISLEY TISSUES        -24
# 238   C536391     21980  PACK OF 12 RED RETROSPOT TISSUES        -24
# 239   C536391     21484        CHICK GREY HOT WATER BOTTLE       -12
# 240   C536391     22557   PLASTERS IN TIN VINTAGE PAISLEY        -12
# 241   C536391     22553             PLASTERS IN TIN SKULLS       -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 238 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 239 2010-12-01 10:24:00       3.45     17548.0  United Kingdom
# ...

# %%
df[df.InvoiceNo == "536391"]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df[df.UnitPrice < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %% [markdown]
# ### ii. What does the letter "C" in the InvoiceNo column mean?

# %% [markdown]
# hint: If the invoice number starts with the letter "C", it means the order was cancelled. Or those who abandon their order.

# %%
df.InvoiceNo.str.startswith("C", na=False).sum()
# Out:
# 9251

# %% [markdown]
# When we filter canceled orders by Quantity> 0 or filter non-canceled orders by Quantity <0 nothing returns, this confirms that negative values mean the order was canceled. So lets find out how many orders were cancelled?

# %%
df[df.Quantity < 0]["Quantity"].count()
# Out:
# 10587

# %%
df["Cancelled"] = df.InvoiceNo.str.startswith("C", na=False)
df.Cancelled.value_counts()
# Out:
# False    527390
# True       9251
# Name: Cancelled, dtype: int64

# %%
len(df[(df.Cancelled == True) & (df.Quantity >= 0)])
# Out:
# 0

# %%
len(df[(df.Cancelled == False) & (df.Quantity <= 0)])
# Out:
# 1336

# %%
cancelled_order = df[df.Cancelled == True]["InvoiceNo"].nunique()
invoice_number = df.InvoiceNo.nunique()

print(f"Total Orders: {invoice_number} \
     \nCancelled num of orders: {cancelled_order} \
     \nCancelation ratio:{cancelled_order/invoice_number:.2} ")
# Out:
# Total Orders: 25900
# Cancelled num of orders: 3836
# Cancelation ratio:0.15

# %%
from seaborn.widgets import color_palette
f, ax = plt.subplots(figsize = (7,7))
ax.pie([cancelled_order,invoice_number-cancelled_order],
       labels = ("Cancelled orders","Completed Order"),
       autopct = "%.1f%%",
       explode = (0,0.1),
       shadow = True,
       colors = ['lightskyblue', 'gold'],
       textprops={"fontsize": 12});

# %% [markdown]
# #### Looking deeper into why these orders were cancelled may prevent future cancellations. Now let's find out what a negative UnitPrice means.

# %%
df[df["UnitPrice"] < 0]
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country  Cancelled
# 299983  -11062.06         NaN  United Kingdom      False
# 299984  -11062.06         NaN  United Kingdom      False

# %%
# Adjust bad debt bir alacaklıya ödenmesi muhtemel olmayan ve alacaklının genellikle borçlunun alacak parası olmaması nedeniyle çeşitli nedenlerle 
# tahsil etmek için harekete geçmeye istekli olmadığı parasal bir miktar olarak tanımlanmakta.

# %%
df[df["UnitPrice"] < 0]["UnitPrice"].sum() # Toplam bad dapt 22124 Sterlin
# Out:
# -22124.12

# %%
((df[df["Cancelled"] == True]["Quantity"]) * (df[df["Cancelled"] == True]["UnitPrice"])).sum()
# İptal edilen sipariş tutarı 893.979 Sterlin
# Out:
# -893979.7300000001

# %%
neg_quantity = df[(df.Cancelled == False) & (df.Quantity < 0)]
neg_quantity
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 2406      536589     21777         NaN       -10 2010-12-01 16:50:00
# 4347      536764    84952C         NaN       -38 2010-12-02 14:42:00
# 7188      536996     22712         NaN       -20 2010-12-03 15:30:00
# 7189      536997     22028         NaN       -20 2010-12-03 15:30:00
# 7190      536998     85067         NaN        -6 2010-12-03 15:30:00
# ...          ...       ...         ...       ...                 ...
# 535333    581210     23395       check       -26 2011-12-07 18:36:00
# 535335    581212     22578        lost     -1050 2011-12-07 18:38:00
# 535336    581213     22576       check       -30 2011-12-07 18:38:00
# 536908    581226     23090     missing      -338 2011-12-08 09:56:00
# 538919    581422     23169     smashed      -235 2011-12-08 15:24:00
#
#         UnitPrice  CustomerID         Country  Cancelled
# 2406          0.0         NaN  United Kingdom      False
# ...

# %%
neg_quantity["InvoiceNo"].nunique()
# Out:
# 1336

# %%
neg_quantity.Description.value_counts(dropna=False)
# İptal edilmemiş fakat genelde Kayıp vb durumdaki siparişlerdeki adet miktarı da negatif belirtilmiş.
# Bu siparişler için de damaged adlı yeni sütun oluşturduk.
# Out:
# NaN                                    862
# check                                  120
# damages                                 45
# damaged                                 42
# ?                                       41
#                                       ...
# POSSIBLE DAMAGES OR LOST?                1
# MERCHANT CHANDLER CREDIT ERROR, STO      1
# mystery! Only ever imported 1800         1
# sold as 22467                            1
# lost                                     1
# Name: Description, Length: 139, dtype: int64

# %%
df["Damaged"] = False
df["Damaged"].loc[neg_quantity.index] = True
# Out:
# C:\Users\mhsna\AppData\Local\Temp\ipykernel_8400\3883116329.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Damaged"].loc[neg_quantity.index] = True

# %%
df[df.Damaged == True]["Damaged"].sum()
# Bad Dapt İade Kargo ücretleri, Kayıp, Hatalı ürünler vb de olabilir.
# Out:
# 1336

# %%
damaged_order = df[df.Damaged == True]["Damaged"].sum()

print(f"Total Orders: {invoice_number} \
     \nDamaged num of orders: {damaged_order} \
     \nDamaged ratio:{damaged_order/invoice_number:.2} ")
# Out:
# Total Orders: 25900
# Damaged num of orders: 1336
# Damaged ratio:0.052

# %%
from seaborn.widgets import color_palette
f, ax = plt.subplots(figsize = (7,7))
ax.pie([damaged_order,invoice_number-damaged_order],
       labels = ("Damaged Orders","Total Orders"),
       autopct = "%.1f%%",
       explode = (0,0.1),
       shadow = True,
       colors = ['lightskyblue', 'gold'],
       textprops={"fontsize": 12});

# %%
top 20 who has the most transactions

# %% [markdown]
# ### iii. Handling Missing Values

# %% [markdown]
# Since the customer ID's are missing, lets assume these orders were not made by the customers already in the data set because those customers already have ID's.
#
# We also don't want to assign these orders to those customers because this would alter the insights we draw from the data.

# %%
df.isna().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135037
# Country             0
# Cancelled           0
# Damaged             0
# dtype: int64

# %%
df[df["CustomerID"].isna()]
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 622       536414     22139                              NaN        56
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Cancelled  \
# ...

# %%
df[(df["UnitPrice"] == 0) & (df["CustomerID"].isna())]
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 622       536414     22139                           NaN        56
# 1970      536545     21134                           NaN         1
# 1971      536546     22145                           NaN         1
# 1972      536547     37509                           NaN         1
# 1987      536549    85226A                           NaN         1
# ...          ...       ...                           ...       ...
# 536981    581234     72817                           NaN        27
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538554    581408     85175                           NaN        20
# 538919    581422     23169                       smashed      -235
#
#                InvoiceDate  UnitPrice  CustomerID         Country  Cancelled  \
# 622    2010-12-01 11:52:00        0.0         NaN  United Kingdom      False
# ...

# %% [markdown]
# ### iv. Clean the Data from the Noise and Missing Values

# %%
df.dropna(subset=["CustomerID"], inplace=True)
df.CustomerID.isna().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401604 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    401604 non-null  object
#  1   StockCode    401604 non-null  object
#  2   Description  401604 non-null  object
#  3   Quantity     401604 non-null  int64
#  4   InvoiceDate  401604 non-null  datetime64[ns]
#  5   UnitPrice    401604 non-null  float64
#  6   CustomerID   401604 non-null  float64
#  7   Country      401604 non-null  object
#  8   Cancelled    401604 non-null  bool
#  9   Damaged      401604 non-null  bool
# dtypes: bool(2), datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 28.3+ MB

# %%
plt.figure(figsize=(16,6))

plt.subplot(2,1,1)
sns.boxplot(x=df["Quantity"])

plt.subplot(2,1,2)
sns.boxplot(x=df["UnitPrice"]);

# %%
df = df[(df["Quantity"] > 0) & (df["Quantity"] < 10000)]
df = df[(df["UnitPrice"] < 5000)]
df.shape
# Out:
# (392728, 10)

# %%
plt.figure(figsize=(16,6))

plt.subplot(2,1,1)
sns.boxplot(x=df["Quantity"])

plt.subplot(2,1,2)
sns.boxplot(x=df["UnitPrice"]);

# %% [markdown]
# ### v. Explore the Orders

# %% [markdown]
# 1. Find the unique number of InvoiceNo  per customer

# %%
df.groupby(["CustomerID"])["InvoiceNo"].nunique()
# Out:
# CustomerID
# 12347.0     7
# 12348.0     4
# 12349.0     1
# 12350.0     1
# 12352.0     8
#            ..
# 18280.0     1
# 18281.0     1
# 18282.0     2
# 18283.0    16
# 18287.0     3
# Name: InvoiceNo, Length: 4337, dtype: int64

# %%
top müşteri vb.

# %% [markdown]
# 2. What's the average number of unqiue items per order or per customer?

# %%
df.groupby(["CustomerID","StockCode"])["Quantity"].mean()
# Out:
# CustomerID  StockCode
# 12347.0     16008        24.0
#             17021        36.0
#             20665         6.0
#             20719        10.0
#             20780        12.0
#                          ...
# 18287.0     72351B       24.0
#             84507C        6.0
#             85039A       48.0
#             85039B       40.0
#             85040A       24.0
# Name: Quantity, Length: 266798, dtype: float64

# %%
df.groupby(['InvoiceNo', 'StockCode'])['Quantity'].mean()
# Out:
# InvoiceNo  StockCode
# 536365     21730        6.0
#            22752        2.0
#            71053        6.0
#            84029E       6.0
#            84029G       6.0
#                        ...
# 581587     22730        4.0
#            22899        6.0
#            23254        4.0
#            23255        4.0
#            23256        4.0
# Name: Quantity, Length: 387871, dtype: float64

# %% [markdown]
# 3. Let's see how this compares to the number of unique products per customer.

# %%
df.groupby(["CustomerID","StockCode"])[["Quantity"]].sum()
# Out:
#                       Quantity
# CustomerID StockCode
# 12347.0    16008            24
#            17021            36
#            20665             6
#            20719            40
#            20780            12
# ...                        ...
# 18287.0    72351B           24
#            84507C            6
#            85039A           96
#            85039B          120
#            85040A           48
#
# [266798 rows x 1 columns]

# %% [markdown]
# ### vi. Explore Customers by Country

# %% [markdown]
# 1. What's the total revenue per country?

# %%
df["Reveneu"] = df["Quantity"] * df["UnitPrice"]

# %%
reveneu_country = df.groupby("Country")["Reveneu"].sum().sort_values(ascending=False)
reveneu_country
# Out:
# Country
# United Kingdom    7031228.694
# Netherlands        285446.340
# EIRE               265262.460
# Germany            228678.400
# France             208934.310
#                      ...
# Brazil               1143.600
# RSA                  1002.310
# Czech Republic        826.740
# Bahrain               548.400
# Saudi Arabia          145.920
# Name: Reveneu, Length: 37, dtype: float64

# %% [markdown]
# 2. Visualize number of customer per country

# %%
customer_country = df.groupby("Country")["CustomerID"].nunique().sort_values(ascending=False)

# %%
fig, ax = plt.subplots(figsize=(8,12))
ax = sns.barplot(y=customer_country.index, x=customer_country.values)
ax.bar_label(ax.containers[0], size=9)
ax.set_title("Customers by Country");

# %% [markdown]
# 3. Visualize total cost per country

# %%
fig, ax = plt.subplots(figsize=(8,12))
ax = sns.barplot(y=reveneu_country.index, x=reveneu_country.values)
ax.bar_label(ax.containers[0], size=9)
ax.set_title("Total Cost per Country");

# %% [markdown]
# #### The UK not only has the most sales revenue, but also the most customers. Since the majority of this data set contains orders from the UK, we can explore the UK market further by finding out what products the customers buy together and any other buying behaviors to improve our sales and targeting strategy.

# %% [markdown]
# ### vii. Explore the UK Market

# %% [markdown]
# 1. Create df_uk DataFrame

# %%
df_uk = df[df["Country"] == "United Kingdom" ]
df_uk.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  ...  CustomerID         Country Cancelled  Damaged  \
# 0 2010-12-01 08:26:00  ...     17850.0  United Kingdom     False    False
# 1 2010-12-01 08:26:00  ...     17850.0  United Kingdom     False    False
# 2 2010-12-01 08:26:00  ...     17850.0  United Kingdom     False    False
# 3 2010-12-01 08:26:00  ...     17850.0  United Kingdom     False    False
# 4 2010-12-01 08:26:00  ...     17850.0  United Kingdom     False    False
#
#    Reveneu
# 0    15.30
# 1    20.34
# 2    22.00
# 3    20.34
# 4    20.34
#
# [5 rows x 11 columns]

# %% [markdown]
# 2. What are the most popular products that are bought in the UK?

# %%
df_uk.groupby("StockCode")["Quantity"].sum().sort_values(ascending=False).head(10)
# Out:
# StockCode
# 84077     49086
# 22197     45609
# 85099B    41878
# 85123A    34687
# 84879     32628
# 22616     24321
# 17003     22675
# 21212     22442
# 22178     21876
# 21977     19959
# Name: Quantity, dtype: int64

# %%
df_uk = df_uk.drop(df_uk[df_uk["Cancelled"] == True ].index)

# %%
df_uk.drop(["Cancelled", "Damaged"], axis=1, inplace=True)

# %%
df_uk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349223 entries, 0 to 541893
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349223 non-null  object
#  1   StockCode    349223 non-null  object
#  2   Description  349223 non-null  object
#  3   Quantity     349223 non-null  int64
#  4   InvoiceDate  349223 non-null  datetime64[ns]
#  5   UnitPrice    349223 non-null  float64
#  6   CustomerID   349223 non-null  float64
#  7   Country      349223 non-null  object
#  8   Reveneu      349223 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(4)
# memory usage: 26.6+ MB

# %%
df_uk.to_csv("df_uk.csv", index=False)

# %% [markdown]
# ### We will continue analyzing the UK transactions with customer segmentation.

# %% [markdown]
# # 2. RFM Analysis

# %% [markdown]
# In the age of the internet and e-commerce, companies that do not expand their businesses online or utilize digital tools to reach their customers will run into issues like scalability and a lack of digital precsence. An important marketing strategy e-commerce businesses use for analyzing and predicting customer value is customer segmentation. Customer data is used to sort customers into group based on their behaviors and preferences.
#
# **[RFM](https://www.putler.com/rfm-analysis/) (Recency, Frequency, Monetary) Analysis** is a customer segmentation technique for analyzing customer value based on past buying behavior. RFM analysis was first used by the direct mail industry more than four decades ago, yet it is still an effective way to optimize your marketing.
# <br>
# <br>
# Our goal in this Notebook is to cluster the customers in our data set to:
#  - Recognize who are our most valuable customers
#  - Increase revenue
#  - Increase customer retention
#  - Learn more about the trends and behaviors of our customers
#  - Define customers that are at risk
#
# We will start with **RFM Analysis** and then compliment our findings with predictive analysis using **K-Means Clustering Algorithms.**
#
# - RECENCY (R): Time since last purchase
# - FREQUENCY (F): Total number of purchases
# - MONETARY VALUE (M): Total monetary value
#
#
#
#
# Benefits of RFM Analysis
#
# - Increased customer retention
# - Increased response rate
# - Increased conversion rate
# - Increased revenue
#
# RFM Analysis answers the following questions:
#  - Who are our best customers?
#  - Who has the potential to be converted into more profitable customers?
#  - Which customers do we need to retain?
#  - Which group of customers is most likely to respond to our marketing campaign?

# %% [markdown]
# ### i. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import seaborn as sns

# %% [markdown]
# ### ii. Review df_uk DataFrame

# %%
df_uk = pd.read_csv("df_uk.csv")

# %%
df = df_uk.copy()
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Reveneu
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349223 entries, 0 to 349222
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349223 non-null  int64
#  1   StockCode    349223 non-null  object
#  2   Description  349223 non-null  object
#  3   Quantity     349223 non-null  int64
#  4   InvoiceDate  349223 non-null  object
#  5   UnitPrice    349223 non-null  float64
#  6   CustomerID   349223 non-null  float64
#  7   Country      349223 non-null  object
#  8   Reveneu      349223 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 24.0+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %% [markdown]
# ### iii. Recency: Days since last purchase
# To calculate the recency values, follow these steps in order:
#
# 1. To calculate recency, we need to choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.
# 2. Create a new column called Date which contains the invoice date without the timestamp
# 3. Group by CustomerID and check the last date of purchase
# 4. Calculate the days since last purchase
# 5. Drop Last_Purchase_Date since we don't need it anymore
# 6. Plot RFM distributions

# %% [markdown]
# 1. Choose a date as a point of reference to evaluate how many days ago was the customer's last purchase.

# %%
df.InvoiceDate.max(),df.InvoiceDate.min()
# Out:
# (Timestamp('2011-12-09 12:49:00'), Timestamp('2010-12-01 08:26:00'))

# %%
current_date = df.InvoiceDate.max()
print(current_date)
# Analizi son güne göre yapacağız
# Out:
# 2011-12-09 12:49:00

# %% [markdown]
# 2. Create a new column called Date which contains the invoice date without the timestamp

# %%
df["Date"] = df["InvoiceDate"].dt.date

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Reveneu  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
#
#          Date
# 0  2010-12-01
# 1  2010-12-01
# 2  2010-12-01
# 3  2010-12-01
# 4  2010-12-01

# %% [markdown]
# 3. Group by CustomerID and check the last date of purchase

# %%
df.groupby("CustomerID")["Date"].max()
# Out:
# CustomerID
# 12747.0    2011-12-07
# 12748.0    2011-12-09
# 12749.0    2011-12-06
# 12820.0    2011-12-06
# 12821.0    2011-05-09
#               ...
# 18280.0    2011-03-07
# 18281.0    2011-06-12
# 18282.0    2011-12-02
# 18283.0    2011-12-06
# 18287.0    2011-10-28
# Name: Date, Length: 3919, dtype: object

# %%
df["LastPurchaseDate"] = df.groupby("CustomerID")["Date"].transform(max)

# %% [markdown]
# 4. Calculate the days since last purchase

# %%
df["LastOrderDays"] = current_date.date() - df["LastPurchaseDate"]

# %%
df["LastOrderDays"].value_counts()
# Out:
# 1 days      31709
# 4 days      19843
# 2 days      18224
# 3 days      13751
# 0 days      12341
#             ...
# 298 days       15
# 339 days       11
# 270 days        5
# 150 days        4
# 324 days        1
# Name: LastOrderDays, Length: 302, dtype: int64

# %% [markdown]
# 5. Drop Last_Purchase_Date since we don't need it anymore

# %%
df.drop(["LastPurchaseDate"],axis=1,inplace=True)

# %%
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  ...  CustomerID         Country Reveneu        Date  \
# 0 2010-12-01 08:26:00  ...     17850.0  United Kingdom   15.30  2010-12-01
# 1 2010-12-01 08:26:00  ...     17850.0  United Kingdom   20.34  2010-12-01
# 2 2010-12-01 08:26:00  ...     17850.0  United Kingdom   22.00  2010-12-01
# 3 2010-12-01 08:26:00  ...     17850.0  United Kingdom   20.34  2010-12-01
# 4 2010-12-01 08:26:00  ...     17850.0  United Kingdom   20.34  2010-12-01
#
#   LastOrderDays
# 0      372 days
# 1      372 days
# 2      372 days
# 3      372 days
# ...

# %% [markdown]
# 6. Plot RFM distributions

# %%
df.groupby("CustomerID")["LastOrderDays"].max()
# Out:
# CustomerID
# 12747.0     2 days
# 12748.0     0 days
# 12749.0     3 days
# 12820.0     3 days
# 12821.0   214 days
#             ...
# 18280.0   277 days
# 18281.0   180 days
# 18282.0     7 days
# 18283.0     3 days
# 18287.0    42 days
# Name: LastOrderDays, Length: 3919, dtype: timedelta64[ns]

# %%
df_rfm = pd.DataFrame()

# %%
df_rfm["Recency"] = df.groupby("CustomerID")["LastOrderDays"].max().dt.days

# %%
df_rfm
# Out:
#             Recency
# CustomerID
# 12747.0           2
# 12748.0           0
# 12749.0           3
# 12820.0           3
# 12821.0         214
# ...             ...
# 18280.0         277
# 18281.0         180
# 18282.0           7
# 18283.0           3
# 18287.0          42
#
# [3919 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.histplot( data=df_rfm, x="Recency", bins=20)
ax.bar_label(ax.containers[0])
ax.set_title("Recency");

# %% [markdown]
# ### iv. Frequency: Number of purchases
#
# To calculate how many times a customer purchased something, we need to count how many invoices each customer has. To calculate the frequency values, follow these steps in order:

# %% [markdown]
# 1. Make a copy of df_uk and drop duplicates

# %%
df.groupby(["CustomerID"])["InvoiceNo"].nunique()
# Out:
# CustomerID
# 12747.0     11
# 12748.0    210
# 12749.0      5
# 12820.0      4
# 12821.0      1
#           ...
# 18280.0      1
# 18281.0      1
# 18282.0      2
# 18283.0     16
# 18287.0      3
# Name: InvoiceNo, Length: 3919, dtype: int64

# %% [markdown]
# 2. Calculate the frequency of purchases

# %%
df_rfm["Frequency"] = df.groupby(["CustomerID"])["InvoiceNo"].nunique()

# %%
df_rfm.head()
# Out:
#             Recency  Frequency
# CustomerID
# 12747.0           2         11
# 12748.0           0        210
# 12749.0           3          5
# 12820.0           3          4
# 12821.0         214          1

# %% [markdown]
# 3. Plot RFM distributions

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.histplot( data=df_rfm, x="Frequency", bins=20)
ax.bar_label(ax.containers[0])
ax.set_title("Frequency");

# %% [markdown]
# ### v. Monetary: Total amount of money spent
#
# The monetary value is calculated by adding together the cost of the customers' purchases.

# %% [markdown]
# 1. Calculate sum total cost by customers and named "Monetary"

# %%
df.groupby("CustomerID")["Reveneu"].sum()
# Out:
# CustomerID
# 12747.0     4196.01
# 12748.0    33053.19
# 12749.0     4090.88
# 12820.0      942.34
# 12821.0       92.72
#              ...
# 18280.0      180.60
# 18281.0       80.82
# 18282.0      178.05
# 18283.0     2045.53
# 18287.0     1837.28
# Name: Reveneu, Length: 3919, dtype: float64

# %%
df_rfm["Monetary"] = df.groupby("CustomerID")["Reveneu"].sum()

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12747.0           2         11   4196.01
# 12748.0           0        210  33053.19
# 12749.0           3          5   4090.88
# 12820.0           3          4    942.34
# 12821.0         214          1     92.72

# %% [markdown]
# 2. Plot RFM distributions

# %%
fig, ax = plt.subplots(figsize=(12,8))
ax = sns.histplot( data=df_rfm, x="Monetary", bins=20)
ax.bar_label(ax.containers[0])
ax.set_title("Monetary");

# %% [markdown]
# ### vi. Create RFM Table
# Merge the recency, frequency and motetary dataframes

# %%
df_rfm.sample(10)
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 15774.0          68          1    270.80
# 15679.0          24          4    781.28
# 17680.0          23          1    184.40
# 13837.0         211          2    266.59
# 18250.0         310          1    349.27
# 15581.0         120         13   3675.77
# 14850.0         311          1    325.75
# 16053.0          32          2   1511.95
# 15506.0          22          3    972.08
# 14655.0           8          4   1932.23

# %% [markdown]
# # 3. Customer Segmentation with RFM Scores

# %% [markdown]
# Businesses have this ever-lasting urge to understand their customers. The better you understand the customer, the better you serve them, and the higher the financial gain you receive from that customer. Since the dawn of trade, this process of understanding customers for a strategic gain has been there practiced and this task is known majorly as [Customer Segmentation](https://clevertap.com/blog/rfm-analysis/).
# Well as the name suggests, Customer Segmentation could segment customers according to their precise needs. Some of the common ways of segmenting customers are based on their Recency-Frequency-Monatory values, their demographics like gender, region, country, etc, and some of their business-crafted scores. You will use Recency-Frequency-Monatory values for this case.
#
# In this section, you will create an RFM Segmentation Table where you segment your customers by using the RFM table. For example, you can label the best customer as "Big Spenders" and the lost customer as "Lost Customer".

# %% [markdown]
# ## Calculate RFM Scoring
#
# The simplest way to create customer segments from an RFM model is by using **Quartiles**. We will assign a score from 1 to 4 to each category (Recency, Frequency, and Monetary) with 4 being the highest/best value. The final RFM score is calculated by combining all RFM values. For Customer Segmentation, you will use the df_rfm data set resulting from the RFM analysis.
# <br>
# <br>
# **Note**: Data can be assigned into more groups for better granularity, but we will use 4 in this case.

# %%
df_rfm.describe()
# Out:
#            Recency    Frequency       Monetary
# count  3919.000000  3919.000000    3919.000000
# mean     91.734881     4.247257    1794.138478
# std      99.482068     7.205250    6862.656975
# min       0.000000     1.000000       2.900000
# 25%      17.000000     1.000000     298.055000
# 50%      50.000000     2.000000     643.900000
# 75%     142.000000     5.000000    1567.585000
# max     373.000000   210.000000  259657.300000

# %% [markdown]
# ### i. Creating the RFM Segmentation Table

# %% [markdown]
# 1. Create two functions, one for Recency and one for Frequency and Monetary. For Recency, customers in the first quarter should be scored as 4, this represents the highest Recency value. Conversely, for Frequency and Monetary, customers in the last quarter should be scored as 4, representing the highest Frequency and Monetary values.

# %%
#Rfm 
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]: 
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4
def RScoreRec(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]: 
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1

# %%
quantiles = df_rfm.quantile(q=[0.25,0.5,0.75])
quantiles = quantiles.to_dict()

# Recency
df_rfm['RecencyTile'] = df_rfm['Recency'].apply(RScoreRec, args=('Recency',quantiles,))


# Frequency        

df_rfm['FrequencyTile'] = df_rfm['Frequency'].apply(RScore, args=('Frequency',quantiles,))

# Monetary 
#df_rfm.sort_values('Monetary',ascending=False)
df_rfm['MonetaryTile'] = df_rfm['Monetary'].apply(RScore, args=('Monetary',quantiles,))

# #'Sıfır' değeri yer almasın istiyorsak, bulduğumuz değerleri 1 arttırıyoruz
# df_rfm['RecencyTile'] = df_rfm['RecencyTile'] +1
# df_rfm['FrequencyTile'] = df_rfm['FrequencyTile'] 
# df_rfm['MonetaryTile'] = df_rfm['MonetaryTile'] +1
#Bulduğumuz değerleri birleştirip rfm skor elde ediyoruz
df_rfm['RFM_Score'] = df_rfm['RecencyTile'].map(str) + df_rfm['FrequencyTile'].map(str) + df_rfm['MonetaryTile'].map(str)
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  RecencyTile  FrequencyTile  \
# CustomerID
# 12747.0           2         11   4196.01            4              4
# 12748.0           0        210  33053.19            4              4
# 12749.0           3          5   4090.88            4              3
# 12820.0           3          4    942.34            4              3
# 12821.0         214          1     92.72            1              1
#
#             MonetaryTile RFM_Score
# CustomerID
# 12747.0                4       444
# 12748.0                4       444
# 12749.0                4       434
# 12820.0                3       433
# 12821.0                1       111

# %% [markdown]
# 4. Define rfm_level function that tags customers by using RFM_Scrores and Create a new variable RFM_Level

# %%
df_rfm["RFM_Level"] = df_rfm["FrequencyTile"]+df_rfm["RecencyTile"]+df_rfm["MonetaryTile"]

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  RecencyTile  FrequencyTile  \
# CustomerID
# 12747.0           2         11   4196.01            4              4
# 12748.0           0        210  33053.19            4              4
# 12749.0           3          5   4090.88            4              3
# 12820.0           3          4    942.34            4              3
# 12821.0         214          1     92.72            1              1
#
#             MonetaryTile RFM_Score  RFM_Level
# CustomerID
# 12747.0                4       444         12
# 12748.0                4       444         12
# 12749.0                4       434         11
# 12820.0                3       433         10
# 12821.0                1       111          3

# %% [markdown]
# 5. Calculate average values for each RFM_Level, and return a size of each segment

# %%
df_rfm.RFM_Level.value_counts()
# Out:
# 4     455
# 5     448
# 12    423
# 9     408
# 6     405
# 3     395
# 7     369
# 8     368
# 10    346
# 11    302
# Name: RFM_Level, dtype: int64

# %%
def rfm_level_segment(data) :
    if data == 12 :
        return 'Best Customer'
    elif data >= 10 :
        return 'Loyal Customer'
    elif data >= 8 :
        return 'Big Spenders'
    elif data >= 6 :
        return 'Almost Lost'
    elif data >= 4 :
        return 'Lost Customers'
    else :
        return 'Lost Cheap Customers'

# %%
df_rfm["RFM_Level"].apply(rfm_level_segment)
# Out:
# CustomerID
# 12747.0           Best Customer
# 12748.0           Best Customer
# 12749.0          Loyal Customer
# 12820.0          Loyal Customer
# 12821.0    Lost Cheap Customers
#                    ...
# 18280.0    Lost Cheap Customers
# 18281.0    Lost Cheap Customers
# 18282.0             Almost Lost
# 18283.0           Best Customer
# 18287.0          Loyal Customer
# Name: RFM_Level, Length: 3919, dtype: object

# %%
df_rfm["LevelSegment"] = df_rfm["RFM_Level"].apply(rfm_level_segment)

# %%
df_rfm["LevelSegment"].sample(15)
# Out:
# CustomerID
# 13538.0          Loyal Customer
# 14623.0            Big Spenders
# 14825.0           Best Customer
# 15042.0    Lost Cheap Customers
# 14745.0            Big Spenders
# 14336.0          Loyal Customer
# 17524.0    Lost Cheap Customers
# 17158.0            Big Spenders
# 18030.0             Almost Lost
# 13351.0          Lost Customers
# 18259.0          Loyal Customer
# 13171.0            Big Spenders
# 15618.0            Big Spenders
# 17002.0            Big Spenders
# 15007.0    Lost Cheap Customers
# Name: LevelSegment, dtype: object

# %% [markdown]
# ## Plot RFM Segments

# %% [markdown]
# 1. Create your plot and resize it.

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  RecencyTile  FrequencyTile  \
# CustomerID
# 12747.0           2         11   4196.01            4              4
# 12748.0           0        210  33053.19            4              4
# 12749.0           3          5   4090.88            4              3
# 12820.0           3          4    942.34            4              3
# 12821.0         214          1     92.72            1              1
#
#             MonetaryTile RFM_Score  RFM_Level          LevelSegment
# CustomerID
# 12747.0                4       444         12         Best Customer
# 12748.0                4       444         12         Best Customer
# 12749.0                4       434         11        Loyal Customer
# 12820.0                3       433         10        Loyal Customer
# 12821.0                1       111          3  Lost Cheap Customers

# %%
plt.figure(figsize=(15,15))
plt.subplot(3,1,1)
sns.boxplot(y="LevelSegment", x="Recency", data=df_rfm)
plt.subplot(3,1,2)
sns.boxplot(y="LevelSegment", x="Frequency", data=df_rfm)
plt.subplot(3,1,3)
sns.boxplot(y="LevelSegment", x="Monetary", data=df_rfm);

# %%
Almost-lost, big spenders , loyal customerdüzenlenmebilir(Recency de)
monetrey best customer

# %% [markdown]
# Using customer segmentation categories found [here](http://www.blastam.com/blog/rfm-analysis-boosts-sales). We can formulate different marketing strategies and approaches for customer engagement for each type of customer.
#
# Note: The author in the article scores 1 as the highest and 4 as the lowest

# %% [markdown]
# 2. How many customers do we have in each segment?

# %%
fig, ax = plt.subplots(figsize=(10,6))
ax = sns.countplot(x=df_rfm["LevelSegment"],
                    order = df_rfm["LevelSegment"].value_counts().index)
ax.bar_label(ax.containers[0], size=12);

# %%
colors_list = ['gold', 'pink', 'lightgreen', 'lightskyblue', 'lightcoral',  'yellowgreen']
explode_list = [0.2, 0, 0, 0, 0, 0]
plt.pie(df_rfm["LevelSegment"].value_counts(),
        labels = df_rfm["LevelSegment"].value_counts().index,
        labeldistance=1.05, 
        autopct="%.1f%%",
        radius=2.0,  
        startangle=90, 
        shadow=True, 
        pctdistance=0.6, 
        colors=colors_list, 
        explode=explode_list);

# %% [markdown]
# # 3. Applying K-Means Clustering

# %% [markdown]
# Now that we have our customers segmented into different categories, we can gain further insight into customer behavior by using predictive models in conjuction with out RFM model.
# Possible algorithms include **Logistic Regression**, **K-means Clustering**, and **K-nearest Neighbor**. We will go with [K-Means](https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1) since we already have our distinct groups determined. K-means has also been widely used for market segmentation and has the advantage of being simple to implement.

# %% [markdown]
# ## Data Pre-Processing and Exploring

# %%
df = df_rfm[["Recency","Frequency","Monetary"]]

# %%
df.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12747.0           2         11   4196.01
# 12748.0           0        210  33053.19
# 12749.0           3          5   4090.88
# 12820.0           3          4    942.34
# 12821.0         214          1     92.72

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3919 entries, 12747.0 to 18287.0
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Recency    3919 non-null   int64
#  1   Frequency  3919 non-null   int64
#  2   Monetary   3919 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 251.5 KB

# %% [markdown]
# ### i. Define and Plot Feature Correlations

# %% [markdown]
# Create Heatmap and evaluate the results

# %%
plt.figure(figsize=(8,6))
sns.heatmap(data=df.corr(), annot=True);

# %% [markdown]
# ### ii. Visualize Feature Distributions
#
# To get a better understanding of the dataset, you can costruct a scatter matrix of each of the three features in the RFM data.

# %%
sns.pairplot(df, height=4, aspect =1);

# %% [markdown]
# ### iii. Data Normalization

# %% [markdown]
# 1. Logarithmic Tranformation can be used to normalize the values in a column.
# 2. Plot normalized data with scatter matrix or pairplot. Also evaluate results.

# %%
df_log = df.apply(np.log1p)
df_log.sample(6)
# Out:
#              Recency  Frequency  Monetary
# CustomerID
# 16038.0     2.079442   1.386294  6.158630
# 15953.0     2.772589   2.197225  7.413536
# 14315.0     3.806662   1.945910  7.816872
# 15322.0     4.454347   0.693147  6.523092
# 15504.0     4.406719   0.693147  3.985831
# 17958.0     4.762174   0.693147  6.233351

# %%
sns.pairplot(df_log, height=4, aspect =1)
plt.title("Normalized Data");

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

df_log_scale = scaler.fit_transform(df_log)

df_log_scale = pd.DataFrame(data=df_log_scale, index=df_log.index, columns=df_log.columns)

# %%
sns.pairplot(df_log_scale, height=4, aspect =1)
plt.title("Normalized Data");

# %% [markdown]
# ## K-Means Implementation
#
# For k-means, you have to set k to the number of clusters you want, but figuring out how many clusters is not obvious from the beginning. We will try different cluster numbers and check their [silhouette coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html). The silhouette coefficient for a data point measures how similar it is to its assigned cluster from -1 (dissimilar) to 1 (similar).
# <br>
# <br>
# **Note**: K-means is sensitive to initializations because they are critical to qualifty of optima found. Thus, we will use smart initialization called "Elbow Method".

# %% [markdown]
# ### i. Define the Optimal Number of Clusters

# %% [markdown]
# [The Elbow Method](https://en.wikipedia.org/wiki/Elbow_method_(clustering)

# %%
X = df_log_scale.copy()

# %% [markdown]
# ## Hopkins test

# %%
from sklearn.neighbors import BallTree
import numpy as np
import pandas as pd
def hopkins(data_frame, sampling_size):
    """Assess the clusterability of a dataset. A score between 0 and 1, a score around 0.5 express
    no clusterability and a score tending to 0 express a high cluster tendency.
    Parameters
    ----------
    data_frame : numpy array
        The input dataset
    sampling_size : int
        The sampling size which is used to evaluate the number of DataFrame.
    Returns
    ---------------------
    score : float
        The hopkins score of the dataset (between 0 and 1)
    Examples
    --------
    >>> from sklearn import datasets
    >>> from pyclustertend import hopkins
    >>> X = datasets.load_iris().data
    >>> hopkins(X,150)
    0.16
    """
    if type(data_frame) == np.ndarray:
        data_frame = pd.DataFrame(data_frame)
    # Sample n observations from D : P
    if sampling_size > data_frame.shape[0]:
        raise Exception(
            'The number of sample of sample is bigger than the shape of D')
    data_frame_sample = data_frame.sample(n=sampling_size)
    # Get the distance to their neirest neighbors in D : X
    tree = BallTree(data_frame, leaf_size=2)
    dist, _ = tree.query(data_frame_sample, k=2)
    data_frame_sample_distances_to_nearest_neighbours = dist[:, 1]
    # Randomly simulate n points with the same variation as in D : Q.
    max_data_frame = data_frame.max()
    min_data_frame = data_frame.min()
    uniformly_selected_values_0 = np.random.uniform(min_data_frame[0], max_data_frame[0], sampling_size)
    uniformly_selected_values_1 = np.random.uniform(min_data_frame[1], max_data_frame[1], sampling_size)
    uniformly_selected_observations = np.column_stack((uniformly_selected_values_0, uniformly_selected_values_1))
    if len(max_data_frame) >= 2:
        for i in range(2, len(max_data_frame)):
            uniformly_selected_values_i = np.random.uniform(min_data_frame[i], max_data_frame[i], sampling_size)
            to_stack = (uniformly_selected_observations, uniformly_selected_values_i)
            uniformly_selected_observations = np.column_stack(to_stack)
    uniformly_selected_observations_df = pd.DataFrame(uniformly_selected_observations)
    # Get the distance to their neirest neighbors in D : Y
    tree = BallTree(data_frame, leaf_size=2)
    dist, _ = tree.query(uniformly_selected_observations_df, k=1)
    uniformly_df_distances_to_nearest_neighbours = dist
    # return the hopkins score
    x = sum(data_frame_sample_distances_to_nearest_neighbours)
    y = sum(uniformly_df_distances_to_nearest_neighbours)
    if x + y == 0:
        raise Exception('The denominator of the hopkins statistics is null')
    return x / (x + y)[0]

# %%
hopkins(X, X.shape[0])
# Out:
# 0.05199787527843602

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ## Elbow method

# %%
from sklearn.cluster import KMeans

ssd =[]
for n in range(2,11):
    kmeans=KMeans(n_clusters=n,random_state=42)
    kmeans.fit(df_log)
    ssd.append(kmeans.inertia_)
plt.figure(figsize=(10,6))
plt.plot(range(2, 11), ssd, "bo--")
plt.title('The Elbow Method')
plt.xlabel('No. of Clusters')
plt.ylabel('ssd')
plt.show()

# %%
-pd.Series(ssd).diff()
# Out:
# 0            NaN
# 1    1940.455991
# 2    1354.911088
# 3     697.560884
# 4     576.130631
# 5     334.847478
# 6     301.633091
# 7     263.191502
# 8     202.166511
# dtype: float64

# %%
from yellowbrick.cluster import KElbowVisualizer

model_ = KMeans(random_state=42)
visualizer = KElbowVisualizer(model_, k=(2,9))

visualizer.fit(X)        # Fit the data to the visualizer
visualizer.poof();

# %% [markdown]
# [Silhouette Coefficient](http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html)

# %%
from sklearn.metrics import silhouette_score

# %%
range_n_clusters = range(2,9)
for num_clusters in range_n_clusters:
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, random_state=42)
    kmeans.fit(X)
    cluster_labels = kmeans.labels_
    # silhouette score
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(f"For n_clusters={num_clusters}, the silhouette score is {silhouette_avg}")
# Out:
# For n_clusters=2, the silhouette score is 0.436143557878143
# For n_clusters=3, the silhouette score is 0.3433337293973919
# For n_clusters=4, the silhouette score is 0.33743945317532686
# For n_clusters=5, the silhouette score is 0.31801201021228553
# For n_clusters=6, the silhouette score is 0.3142288208752221
# For n_clusters=7, the silhouette score is 0.3107232723599173
# For n_clusters=8, the silhouette score is 0.30551079157895766

# %%
from yellowbrick.cluster import SilhouetteVisualizer
model = KMeans(n_clusters=3, random_state=42)          # n_clusters=3
visualizer = SilhouetteVisualizer(model)
visualizer.fit(X)   
visualizer.poof();

# %%
model = KMeans(n_clusters=6, random_state=42)          # n_clusters=6
visualizer = SilhouetteVisualizer(model)
visualizer.fit(X)   
visualizer.poof();

# %% [markdown]
# ### ii. Model Fitting

# %%
model_k3 = KMeans(n_clusters=3, random_state=42)
model_k3.fit(X)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df_log_scale['cluster_K3'] = model_k3.predict(X)
df_log_scale
# Out:
#              Recency  Frequency  Monetary  cluster_K3
# CustomerID
# 12747.0    -1.956019   1.668582  1.454026           2
# 12748.0    -2.751618   5.870545  3.116122           2
# 12749.0    -1.747684   0.652667  1.433596           2
# 12820.0    -1.747684   0.385446  0.251855           1
# 12821.0     1.137722  -0.957521 -1.607829           0
# ...              ...        ...       ...         ...
# 18280.0     1.323825  -0.957521 -1.075083           0
# 18281.0     1.013060  -0.957521 -1.717189           0
# 18282.0    -1.245716  -0.363248 -1.086472           1
# 18283.0    -1.747684   2.179079  0.875591           2
# 18287.0    -0.027810   0.058395  0.789163           1
#
# [3919 rows x 4 columns]

# %%
model_k6 = KMeans(n_clusters=6, random_state=42)
model_k6.fit(X)
# Out:
# KMeans(n_clusters=6, random_state=42)

# %%
df_log_scale['cluster_K6'] = model_k6.predict(X)
df_log_scale
# Out:
#              Recency  Frequency  Monetary  cluster_K3  cluster_K6
# CustomerID
# 12747.0    -1.956019   1.668582  1.454026           2           2
# 12748.0    -2.751618   5.870545  3.116122           2           2
# 12749.0    -1.747684   0.652667  1.433596           2           0
# 12820.0    -1.747684   0.385446  0.251855           1           0
# 12821.0     1.137722  -0.957521 -1.607829           0           1
# ...              ...        ...       ...         ...         ...
# 18280.0     1.323825  -0.957521 -1.075083           0           1
# 18281.0     1.013060  -0.957521 -1.717189           0           1
# 18282.0    -1.245716  -0.363248 -1.086472           1           4
# 18283.0    -1.747684   2.179079  0.875591           2           2
# 18287.0    -0.027810   0.058395  0.789163           1           5
#
# [3919 rows x 5 columns]

# %% [markdown]
# ### iii. Visualize the Clusters

# %% [markdown]
# 1. Create a scatter plot and select cluster centers

# %%
df_log_scale.sample(5)
# Out:
#              Recency  Frequency  Monetary  cluster_K3  cluster_K6
# CustomerID
# 17990.0     1.208274   0.058395 -0.070928           0           5
# 14150.0    -0.156484  -0.363248 -0.036251           1           5
# 12908.0     0.996876  -0.363248  0.068215           0           5
# 16427.0     1.286405  -0.363248 -0.843637           0           1
# 15408.0     1.289143  -0.957521 -0.761109           0           1

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True, figsize = (18,10)) # sharey=True and y-axis labels are used in common.
ax1.set_title('Recency-Frequency')
ax1.set_xlabel('Recency')
ax1.set_ylabel('Frequency')
ax1.scatter(df_log_scale["Recency"], df_log_scale["Frequency"], c = model_k3.labels_, cmap = "viridis", alpha=0.8)
ax1.scatter(model_k3.cluster_centers_[:,0], model_k3.cluster_centers_[:,1], s = 300, alpha = 0.7, c='black')

ax2.set_title("Frequency-Monetary")
ax2.set_xlabel('Frequency')
ax2.set_ylabel('Monetary')
ax2.scatter(df_log_scale["Frequency"], df_log_scale["Monetary"], c = model_k3.labels_, cmap ="viridis", alpha=0.8)
ax2.scatter(model_k3.cluster_centers_[:,1], model_k3.cluster_centers_[:,2], s = 300, alpha = 0.7, c='black')

ax3.set_title("Recency-Monetary")
ax3.set_xlabel('Recency')
ax3.set_ylabel('Monetary')
ax3.scatter(df_log_scale["Recency"], df_log_scale["Monetary"], c = model_k3.labels_, cmap ="viridis", alpha=0.8)
ax3.scatter(model_k3.cluster_centers_[:,0], model_k3.cluster_centers_[:,2], s = 300, alpha = 0.7, c='black');

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey = True, figsize = (18,10)) # sharey=True and y-axis labels are used in common.
ax1.set_title('Recency-Frequency')
ax1.set_xlabel('Recency')
ax1.set_ylabel('Frequency')
ax1.scatter(df_log_scale["Recency"], df_log_scale["Frequency"], c = model_k6.labels_, cmap = "viridis", alpha=0.8)
ax1.scatter(model_k6.cluster_centers_[:,0], model_k6.cluster_centers_[:,1], s = 300, alpha = 0.7, c='black')

ax2.set_title("Frequency-Monetary")
ax2.set_xlabel('Frequency')
ax2.set_ylabel('Monetary')
ax2.scatter(df_log_scale["Frequency"], df_log_scale["Monetary"], c = model_k6.labels_, cmap ="viridis", alpha=0.8)
ax2.scatter(model_k6.cluster_centers_[:,1], model_k6.cluster_centers_[:,2], s = 300, alpha = 0.7, c='black')

ax3.set_title("Recency-Monetary")
ax3.set_xlabel('Recency')
ax3.set_ylabel('Monetary')
ax3.scatter(df_log_scale["Recency"], df_log_scale["Monetary"], c = model_k6.labels_, cmap ="viridis", alpha=0.8)
ax3.scatter(model_k6.cluster_centers_[:,0], model_k6.cluster_centers_[:,2], s = 300, alpha = 0.7, c='black');

# %% [markdown]
# 2. Visualize Cluster Id vs Recency, Cluster Id vs Frequency and Cluster Id vs Monetary using Box plot. Also evaluate the results.

# %%
plt.figure(figsize = (15,8))

plt.subplot(1,3,1)
sns.boxplot(x=df_log_scale['cluster_K3'], y=df_log_scale["Recency"])
            
plt.subplot(1,3,2)
sns.boxplot(x=df_log_scale['cluster_K3'], y=df_log_scale["Frequency"])
            
plt.subplot(1,3,3)
sns.boxplot(x=df_log_scale['cluster_K3'], y=df_log_scale["Monetary"]);

# %%
# Recencyi Frequency ve Monetary ddağılımlarına baktığımızda;
# 0: Lost_Customers
# 1: Almost_Lost
# 2: Best_Customers
# diyebiliriz.

# %%
plt.figure(figsize = (15,8))

plt.subplot(1,3,1)
sns.boxplot(x=df_log_scale['cluster_K6'], y=df_log_scale["Recency"])
            
plt.subplot(1,3,2)
sns.boxplot(x=df_log_scale['cluster_K6'], y=df_log_scale["Frequency"])
            
plt.subplot(1,3,3)
sns.boxplot(x=df_log_scale['cluster_K6'], y=df_log_scale["Monetary"]);

# %%
# k=6 için;

# 0:Loyal Customers
# 1:Lost Cheap Customers(Sadece İndirim Kovalıyor)
# 2:Big Spenders(Harcıyor)
# 3:Best Customers
# 4:Almost Lost()
# 5:Lost Customer(),
# diyebilriz

# %% [markdown]
# ### iv. Assign the Label

# %%
df_rfm.head()
# Out:
#             Recency  Frequency  Monetary  RecencyTile  FrequencyTile  \
# CustomerID
# 12747.0           2         11   4196.01            4              4
# 12748.0           0        210  33053.19            4              4
# 12749.0           3          5   4090.88            4              3
# 12820.0           3          4    942.34            4              3
# 12821.0         214          1     92.72            1              1
#
#             MonetaryTile RFM_Score  RFM_Level          LevelSegment
# CustomerID
# 12747.0                4       444         12         Best Customer
# 12748.0                4       444         12         Best Customer
# 12749.0                4       434         11        Loyal Customer
# 12820.0                3       433         10        Loyal Customer
# 12821.0                1       111          3  Lost Cheap Customers

# %%
df_log_scale.head()
# Out:
#              Recency  Frequency  Monetary  cluster_K3  cluster_K6
# CustomerID
# 12747.0    -1.956019   1.668582  1.454026           2           2
# 12748.0    -2.751618   5.870545  3.116122           2           2
# 12749.0    -1.747684   0.652667  1.433596           2           0
# 12820.0    -1.747684   0.385446  0.251855           1           0
# 12821.0     1.137722  -0.957521 -1.607829           0           1

# %%
df_labels = df_log_scale.copy()
df_labels.head()
# Out:
#              Recency  Frequency  Monetary  cluster_K3  cluster_K6
# CustomerID
# 12747.0    -1.956019   1.668582  1.454026           2           2
# 12748.0    -2.751618   5.870545  3.116122           2           2
# 12749.0    -1.747684   0.652667  1.433596           2           0
# 12820.0    -1.747684   0.385446  0.251855           1           0
# 12821.0     1.137722  -0.957521 -1.607829           0           1

# %%
df_labels['LabelsK3'] = df_labels['cluster_K3'].map({0:'Lost Customers',1:'Almost Lost',2:'Best Customers'})

# %%
df_labels['LabelsK6'] = df_labels['cluster_K6'].map({0:"Loyal Customers",
                                                    1:"Lost Cheap Customers",
                                                    2:"Big Spenders",
                                                    3:"Best Customers",
                                                    4:"Almost Lost",
                                                    5:"Lost Customer"})

# %%
df_labels["LevelSegment"] = df_rfm["LevelSegment"]
df_labels.sample(20)
# Out:
#              Recency  Frequency  Monetary  cluster_K3  cluster_K6  \
# CustomerID
# 18006.0    -0.450117  -0.957521 -0.352029           0           4
# 17499.0     1.354429  -0.957521 -0.081139           0           1
# 14155.0     1.294588  -0.957521 -1.410438           0           1
# 15840.0     0.201277  -0.363248 -0.531705           0           4
# 14552.0     0.886605  -0.957521 -1.151213           0           1
# ...              ...        ...       ...         ...         ...
# 16099.0     0.095754   0.058395  0.048567           1           5
# 13330.0     0.530826   0.058395  0.405719           1           5
# 17243.0    -2.249651   2.857126  2.026249           2           2
# 15251.0    -1.084119   1.668582  2.191474           2           2
# 13013.0    -2.249651   1.894514  1.564143           2           2
#
#                   LabelsK3              LabelsK6          LevelSegment
# CustomerID
# 18006.0     Lost Customers           Almost Lost           Almost Lost
# ...

# %% [markdown]
# ### v. Conclusion
#
# Discuss your final results. Compare your own labels from the RFM Customer Segmentation with the labels found by K-Means.

# %% [markdown]
# How we want to continue this analysis depends on how the business plans to use the results and the level of granularity the business stakeholders want to see in the clusters. We can also ask what range of customer behavior from high to low value customers are the stakeholders interested in exploring. From those answers, various methods of clustering can be used and applied on RFM variable or directly on the transaction data set.

# %% [markdown]
# **Annotation:**
#
# Limitations of K-means clustering:
#
# 1. There is no assurance that it will lead to the global best solution.
# 2. Can't deal with different shapes(not circular) and consider one point's probability of belonging to more than one cluster.
#
# These disadvantages of K-means show that for many datasets (especially low-dimensional datasets), it may not perform as well as you might hope.

# %%
df_labels.groupby(["LabelsK3", "LevelSegment"])["LabelsK3"].count()
# Out:
# LabelsK3        LevelSegment
# Almost Lost     Almost Lost             332
#                 Best Customer             7
#                 Big Spenders            772
#                 Loyal Customer          407
# Best Customers  Best Customer           416
#                 Big Spenders              3
#                 Loyal Customer          241
# Lost Customers  Almost Lost             442
#                 Big Spenders              1
#                 Lost Cheap Customers    395
#                 Lost Customers          903
# Name: LabelsK3, dtype: int64

# %%
df_labels.groupby(["LabelsK6", "LevelSegment"])["LabelsK6"].count()
# Out:
# LabelsK6         LevelSegment
# Almost Lost      Almost Lost       335
#                  Big Spenders       63
#                  Lost Customers    336
# Best Customers   Best Customer     101
#                  Big Spenders      151
#                                   ...
# Lost Customer    Loyal Customer      4
# Loyal Customers  Almost Lost        15
#                  Best Customer      41
#                  Big Spenders      204
#                  Loyal Customer    263
# Name: LabelsK6, Length: 19, dtype: int64

# %% [markdown]
# **Conclusion**
#
# * Write down your conclusions about clustering

# %%
# 3 gruba ayırmak istediğimizde RFM ile karşılaştırdığımızda cluster işlemini modelimiz yakın sonuçlar üretmiş
# Sample verimiz ile karşılaştırma işlemini daha yapmadık..

# k=6 için ise RFM ile karşılaştırdığımızda k için 4-5 e indirerek tekrar ihtiyaca göre Segment ayrımı yapmakta fayda olduğu kanaatindeyim.
# Müşteri davranışlarının derinine inerek Segmentlerin değiştirilmesi için daha fazla zamana ihtiyaç vardır.

# %% [markdown]
# # 5. Create Cohort & Conduct Cohort Analysis
# [Cohort Analysis](https://medium.com/swlh/cohort-analysis-using-python-and-pandas-d2a60f4d0a4d) is specifically useful in analyzing user growth patterns for products. In terms of a product, a cohort can be a group of people with the same sign-up date, the same usage starts month/date, or the same traffic source.
# Cohort analysis is an analytics method by which these groups can be tracked over time for finding key insights. This analysis can further be used to do customer segmentation and track metrics like retention, churn, and lifetime value.
#
# For e-commerce organizations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get the following answers to the following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employ to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasonality pattern in Customer behavior?
# - Along with various performance measures/metrics for your organization.

# %% [markdown]
# Since we will be performing Cohort Analysis based on transaction records of customers, the columns we will be dealing with mainly:
# - Invoice Data
# - CustomerID
# - Price
# - Quantity
#
# The following steps will performed to generate the Cohort Chart of Retention Rate:
# - Month Extraction from InvioceDate column
# - Assigning Cohort to Each Transaction
# - Assigning Cohort Index to each transaction
# - Calculating number of unique customers in each Group of (ChortDate,Index)
# - Creating Cohort Table for Retention Rate
# - Creating the Cohort Chart using the Cohort Table
#
# The Detailed information about each step is given below:

# %% [markdown]
# ## Future Engineering

# %% [markdown]
# ### i. Extract the Month of the Purchase
# First we will create a function, which takes any date and returns the formatted date with day value as 1st of the same month and Year.

# %%
df0 = pd.read_csv("df_uk.csv")

# %%
df = df0.copy()
df.head()
# Out:
#    InvoiceNo StockCode                          Description  Quantity  \
# 0     536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365     71053                  WHITE METAL LANTERN         6
# 2     536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country  Reveneu
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom    15.30
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom    22.00
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom    20.34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 349223 entries, 0 to 349222
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    349223 non-null  int64
#  1   StockCode    349223 non-null  object
#  2   Description  349223 non-null  object
#  3   Quantity     349223 non-null  int64
#  4   InvoiceDate  349223 non-null  object
#  5   UnitPrice    349223 non-null  float64
#  6   CustomerID   349223 non-null  float64
#  7   Country      349223 non-null  object
#  8   Reveneu      349223 non-null  float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 24.0+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df['InvoiceMonth'] = df['InvoiceDate'].map(lambda x : dt.datetime(x.year, x.month, 1))
df['InvoiceMonth'].sample(7)
# Out:
# 309693   2011-11-01
# 168534   2011-07-01
# 239347   2011-10-01
# 8344     2010-12-01
# 229381   2011-09-01
# 264592   2011-10-01
# 302174   2011-11-01
# Name: InvoiceMonth, dtype: datetime64[ns]

# %%
df['FirstInvoiceMonth'] = df.groupby('CustomerID')['InvoiceMonth'].transform('min')
df['FirstInvoiceMonth'].sample(7)
# Out:
# 222091   2011-03-01
# 94890    2010-12-01
# 178513   2011-04-01
# 137661   2011-06-01
# 69378    2010-12-01
# 198525   2010-12-01
# 284614   2010-12-01
# Name: FirstInvoiceMonth, dtype: datetime64[ns]

# %%
df["CohortIndex"] = df['InvoiceMonth'].dt.to_period('M').astype(int) - df['FirstInvoiceMonth'].dt.to_period('M').astype(int)+1

# %%
df.sample(10)
# Out:
#         InvoiceNo StockCode                          Description  Quantity  \
# 188632     563703     22759         SET OF 3 NOTEBOOKS IN PARCEL        12
# 108675     552290     20711                      JUMBO BAG TOYS          2
# 20343      539247     22909  SET OF 20 VINTAGE CHRISTMAS NAPKINS         4
# 214602     567099     23182       TOILET SIGN OCCUPIED OR VACANT        24
# 143856     557414     22418               10 COLOUR SPACEBOY PEN        24
# 114816     553155     21621           VINTAGE UNION JACK BUNTING         4
# 119195     553828     21232       STRAWBERRY CERAMIC TRINKET BOX        12
# 193036     564219     21172                    PARTY METAL SIGN         96
# 118518     553683     22995              TRAVEL CARD WALLET SUKI        24
# 185019     563216     79321                        CHILLI LIGHTS         3
#
#                InvoiceDate  ...         Country  Reveneu InvoiceMonth  \
# 188632 2011-08-18 14:02:00  ...  United Kingdom    19.80   2011-08-01
# ...

# %% [markdown]
# ## Create 1st Cohort: User number & Retention Rate

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_user_retention = df.groupby(["FirstInvoiceMonth","CohortIndex" ])["CustomerID"].nunique().reset_index()
cohort_user_retention.head()
# Out:
#   FirstInvoiceMonth  CohortIndex  CustomerID
# 0        2010-12-01            1         815
# 1        2010-12-01            2         289
# 2        2010-12-01            3         263
# 3        2010-12-01            4         304
# 4        2010-12-01            5         293

# %%
pivot_user_retention = pd.pivot_table(data=cohort_user_retention, index="FirstInvoiceMonth",  columns="CohortIndex", values="CustomerID")
pivot_user_retention
# Out:
# CohortIndex           1      2      3      4      5   ...     9      10  \
# FirstInvoiceMonth                                     ...
# 2010-12-01         815.0  289.0  263.0  304.0  293.0  ...  289.0  325.0
# 2011-01-01         357.0   76.0   93.0   84.0  119.0  ...  108.0  117.0
# 2011-02-01         340.0   64.0   66.0   97.0   98.0  ...   90.0  104.0
# 2011-03-01         419.0   64.0  109.0   83.0   94.0  ...  119.0   38.0
# 2011-04-01         277.0   58.0   56.0   60.0   56.0  ...   20.0    NaN
# 2011-05-01         256.0   48.0   44.0   44.0   53.0  ...    NaN    NaN
# 2011-06-01         214.0   38.0   31.0   51.0   51.0  ...    NaN    NaN
# 2011-07-01         169.0   30.0   33.0   39.0   47.0  ...    NaN    NaN
# 2011-08-01         141.0   32.0   32.0   34.0   17.0  ...    NaN    NaN
# 2011-09-01         276.0   63.0   83.0   32.0    NaN  ...    NaN    NaN
# 2011-10-01         324.0   79.0   36.0    NaN    NaN  ...    NaN    NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 1 using seaborn and matplotlib modules

# %%
pivot_user_retention.index = pivot_user_retention.index.astype(str)

# %%
plt.figure(figsize=(18,10))
plt.title('Cohort Analysis - Number of Customers')
sns.heatmap(data = pivot_user_retention, annot = True,cbar = True,fmt='0.3g',vmin = 10,vmax = 100,cmap = "Blues");

# %%
cohort_size = pivot_user_retention.iloc[:,0]
retention = pivot_user_retention.divide(cohort_size, axis = 0)

# %%
retention.index = retention.index.astype(str)

# %%
plt.figure(figsize=(16,9))
plt.title('Cohort Analysis - Retention Rate (%)')
sns.heatmap(data = retention, annot = True, fmt = '.0%', cmap = 'Blues');

# %% [markdown]
# ## Create the 2nd Cohort: Average Quantity Sold

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_avg_quantity = df.groupby(["FirstInvoiceMonth","CohortIndex" ])["Quantity"].mean().reset_index()
cohort_avg_quantity.head()
# Out:
#   FirstInvoiceMonth  CohortIndex   Quantity
# 0        2010-12-01            1  11.363528
# 1        2010-12-01            2  12.863370
# 2        2010-12-01            3  13.931012
# 3        2010-12-01            4  13.872916
# 4        2010-12-01            5  13.343757

# %%
pivot_avg_quantity = pd.pivot_table(data=cohort_avg_quantity, index="FirstInvoiceMonth",  columns="CohortIndex", values="Quantity").round(1)
pivot_avg_quantity
# Out:
# CohortIndex          1     2     3     4     5   ...    9     10    11    12  \
# FirstInvoiceMonth                                ...
# 2010-12-01         11.4  12.9  13.9  13.9  13.3  ...  16.1  16.1  16.7  12.4
# 2011-01-01          9.9   9.6   9.4  15.1  10.1  ...  10.8   8.7   8.6  10.0
# 2011-02-01         11.0  14.0  15.9  12.1  12.3  ...  11.0  12.5  13.8   NaN
# 2011-03-01          9.7  11.4  13.3  10.1  13.5  ...  11.2   9.7   NaN   NaN
# 2011-04-01         10.1  10.2   9.7  11.9  11.9  ...   7.5   NaN   NaN   NaN
# 2011-05-01         10.7   9.4  14.8  12.8  11.0  ...   NaN   NaN   NaN   NaN
# 2011-06-01          9.5  14.8  12.0  12.7   9.8  ...   NaN   NaN   NaN   NaN
# 2011-07-01         10.1  15.0   6.6   8.1   5.8  ...   NaN   NaN   NaN   NaN
# 2011-08-01          9.4   6.0   5.0   5.9   6.6  ...   NaN   NaN   NaN   NaN
# 2011-09-01         11.9   6.1   7.9   9.0   NaN  ...   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 2 using seaborn and matplotlib modules

# %%
pivot_avg_quantity.index = pivot_avg_quantity.index.astype(str)

# %%
plt.figure(figsize=(16,9))
plt.title('Cohort Analysis - Average Quantity Sold')
sns.heatmap(data = pivot_avg_quantity, annot = True,cbar = True,fmt='0.3g',vmin = 10,vmax = 100,cmap = "YlOrRd");

# %% [markdown]
# ## Create the 3rd Cohort: Average Sales

# %% [markdown]
# ### i. Pivot Cohort and Cohort Retention

# %%
cohort_avg_sales = df.groupby(["FirstInvoiceMonth","CohortIndex" ])["Reveneu"].mean().reset_index()
cohort_avg_sales.head()
# Out:
#   FirstInvoiceMonth  CohortIndex    Reveneu
# 0        2010-12-01            1  21.163619
# 1        2010-12-01            2  22.428102
# 2        2010-12-01            3  23.966176
# 3        2010-12-01            4  23.759081
# 4        2010-12-01            5  20.249368

# %%
pivot_avg_sales = pd.pivot_table(data=cohort_avg_sales, index="FirstInvoiceMonth",  columns="CohortIndex", values="Reveneu").round(1)
pivot_avg_sales
# Out:
# CohortIndex          1     2     3     4     5   ...    9     10    11    12  \
# FirstInvoiceMonth                                ...
# 2010-12-01         21.2  22.4  24.0  23.8  20.2  ...  26.2  31.5  31.1  21.7
# 2011-01-01         18.2  18.8  15.4  28.2  18.6  ...  17.8  17.1  18.0  19.0
# 2011-02-01         17.0  20.1  19.4  19.2  17.6  ...  18.2  22.0  23.9   NaN
# 2011-03-01         16.7  20.2  22.7  17.7  20.6  ...  16.5  13.1   NaN   NaN
# 2011-04-01         16.6  20.1  19.2  18.7  19.1  ...  11.5   NaN   NaN   NaN
# 2011-05-01         18.1  17.0  22.0  21.1  18.7  ...   NaN   NaN   NaN   NaN
# 2011-06-01         22.9  15.2  19.6  16.6  13.3  ...   NaN   NaN   NaN   NaN
# 2011-07-01         14.9  24.7  10.3  12.9   9.3  ...   NaN   NaN   NaN   NaN
# 2011-08-01         15.2  13.0  12.1  15.6  17.1  ...   NaN   NaN   NaN   NaN
# 2011-09-01         18.3  11.5  13.7  14.0   NaN  ...   NaN   NaN   NaN   NaN
# ...

# %% [markdown]
# ### ii. Visualize analysis of cohort 3 using seaborn and matplotlib modules

# %%
pivot_avg_sales.index = pivot_avg_sales.index.astype(str)

# %%
plt.figure(figsize=(16,9))
plt.title('Cohort Analysis - Average Sales')
sns.heatmap(data = pivot_avg_sales, annot = True,cbar = True,fmt='0.3g',vmin = 10,vmax = 100,cmap = "viridis");

# %% [markdown]
# For e-commerce organisations, cohort analysis is a unique opportunity to find out which clients are the most valuable to their business. by performing Cohort analysis you can get answers to following questions:
#
# - How much effective was a marketing campaign held in a particular time period?
# - Did the strategy employed to improve the conversion rates of Customers worked?
# - Should I focus more on retention rather than acquiring new customers?
# - Are my customer nurturing strategies effective?
# - Which marketing channels bring me the best results?
# - Is there a seasoanlity pattern in Customer behahiour?

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
